# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime

# %%
companies = ['IBM','AAPL','JNJ']

# %%
LSTM_blocking_PCA_rmse = pd.read_csv('./result/LSTM_blocking_rmse__PCAopen.csv')
LSTM_blocking_no_PCA_rmse = pd.read_csv('./result/LSTM_blocking_rmse__no_PCAopen.csv')

# %%
regression_blocking_PCA_rmse = pd.read_csv('./result/regression_blocking_rmse_PCA_open.csv')
# regression_blocking_no_PCA_rmse = pd.read_csv('./result/regression_blocking_rmse_no_PCA_open.csv')

# %%
for company in companies:
    daily = pd.read_csv('./data/daily_{}.csv'.format(company))
    daily.set_index('Unnamed: 0', inplace=True)
    data = daily[['1. open']]
    data.index = pd.to_datetime(data.index, format="%Y-%m-%d")
    
    fig, ax = plt.subplots()
    
    plt.plot(data['1. open'].index, data['1. open'].values)

    locator = mdates.AutoDateLocator(maxticks=10)
    formatter = mdates.ConciseDateFormatter(locator)
    ax.xaxis.set_major_locator(locator)
    ax.xaxis.set_major_formatter(formatter)

    plt.title("Stock Opening Price for {}".format(company))
    plt.xlabel("Time")
    plt.ylabel("Stock Price ($)")

    plt.show()
    
    fig.savefig('./image/{}_stock_open_price_plot.png'.format(company))
